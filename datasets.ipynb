# %%
from huggingface_hub import notebook_login
from datasets import load_from_disk

# %%
notebook_login()

# %%
ds_dev_emb = load_from_disk("clinical-dataset-cleaned-with_embeddings")

# %%
ds_dev_emb.push_to_hub("Kornimate/medical-research-clean-embeddings")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# ...
