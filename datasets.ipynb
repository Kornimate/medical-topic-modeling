# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("peetertarvas/embeddings-dataset")

print("Path to dataset files:", path)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# ...
# Download already complete (5980924244 bytes).
# Extracting files...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("peetertarvas/embeddings-dataset")
#       6 print("Path to dataset files:", path)
#
# File c:\Users\korni\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\datasets.py:28, in dataset_download(handle, path, force_download)
#      26 h = parse_dataset_handle(handle)
#      27 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 28 return registry.dataset_resolver(h, path, force_download=force_download)
#
# ...
